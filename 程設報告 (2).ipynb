# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"/Users/amysun/Desktop/final/report.csv")
sns.set(style="darkgrid")
sns.barplot(x="month(2019-20)",y="TW catering industry scale (billion)", data=data)
plt.show()

# %%
sns.barplot(x="month(2019-20)",y="TW food delivery platform penetration rate (%)",data=data)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = pd.read_csv("/Users/amysun/Desktop/李韶慈part/消費筆數成長率.csv")
sns.set(style="darkgrid" )
sns.lineplot(x="DATE", y="GROWTH RATE", data=dataset)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = pd.read_csv("/Users/amysun/Desktop/李韶慈part/消費筆數.csv")
sns.set(style="darkgrid" )
sns.barplot(x="DATE", y="TRANSACTIONS", data=dataset)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = pd.read_csv("/Users/amysun/Desktop/李韶慈part/消費金額.csv")
sns.set(style="darkgrid" )
sns.barplot(x="DATE", y="AMOUNT", data=dataset)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = pd.read_csv("/Users/amysun/Desktop/李韶慈part/消費金額成長率.csv")
sns.set(style="darkgrid" )
sns.lineplot(x="DATE", y="GROWTH RATE", data=dataset)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = pd.read_csv("/Users/amysun/Desktop/李韶慈part/消費次數.csv")
sns.set(style="darkgrid" )
sns.lineplot(x="DATE", y="TIMES", data=dataset)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['Arial Unicode MS']
plt.rcParams['axes.unicode_minus']=False

labels = '25歲以下','26~35歲','36~45歲','46~55歲','56歲以上'
size = [17.35,46.5,26.72,7.42,2.02]
separated = (0,.1,.1,0,0)
plt.pie(size,labels=labels,autopct='%1.1f%%',explode=separated)
plt.axis('equal')
plt.show()

# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd
data = pd.read_csv("/Users/amysun/Desktop/黎芸希part/各銀行信用卡流通數量.csv")

plt.rcParams['font.sans-serif']=['Arial Unicode MS']
plt.rcParams['axes.unicode_minus']=False

sns.barplot(x="銀行",y="流通數量（百萬）",data=data)
# Out:
# <AxesSubplot:xlabel='銀行', ylabel='流通數量（百萬）'>

# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd
data = pd.read_csv("/Users/amysun/Desktop/黎芸希part/各年齡層持有的信用卡張數.csv")

plt.rcParams['font.sans-serif']=['Arial Unicode MS']
plt.rcParams['axes.unicode_minus']=False

sns.barplot(x="歲數",y="持有信用卡張數",data=data)
# Out:
# <AxesSubplot:xlabel='歲數', ylabel='持有信用卡張數'>
